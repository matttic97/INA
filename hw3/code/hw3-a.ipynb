# %% [markdown]
# # Homework 3

# %%
# !pip install cdlib
# !pip install leidenalg
# !pip uninstall community
# !pip install python-louvain
#!pip install igraph

import igraph
import infomap
import networkx as nx
from networkx.algorithms import node_classification
import random
from cdlib import algorithms, evaluation, NodeClustering
from community import community_louvain
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import os

# %% [markdown]
# ## 2. Who’s the winner?

# %% [markdown]
# ### (i)

# %%
def build_synhtetic_graph(mu = 0.5):
    G = nx.Graph(name = "girvan_newman")
    n = 72
    cluster_div = 24
    for i in range(n):
        G.add_node(i, cluster = i // cluster_div + 1)
    for i in range(n):
        for j in range(i + 1, n):
            if G.nodes[i]['cluster'] == G.nodes[j]['cluster']:
                if random.random() < 20 * (1 - mu) / (cluster_div-1):
                    G.add_edge(i, j)
            else:
                if random.random() < 20 * mu / (n-cluster_div):
                    G.add_edge(i, j)
    return G

def compare_on_synthetic(algo_fn, mus, iter_num=10):
    nmis = []
    for mu in mus:
        NMI = 0
        for _ in range(iter_num):
            G = build_synhtetic_graph(mu)
            clustered_G = algo_fn(G)
            partition = get_graph_ideal_partition(G) 
            NMI += clustered_G.normalized_mutual_information(partition).score / iter_num
        nmis.append(NMI)
        print("mu={:.2f}, NMI: {:5.3f}".format(mu, NMI))
    return nmis
        
def get_graph_ideal_partition(G):
    P = {}
    for node in G.nodes(data = True):
        if node[1]['cluster'] not in P:
            P[node[1]['cluster']] = []
        P[node[1]['cluster']].append(node[0])
    node_clusters = P.values()
    return NodeClustering(list(node_clusters), G, 'Ideal')

def run():
    iter_num = 25
    mus = [0.1 * i for i in range(0, 6)]
    algs = {
        "Louvain": algorithms.louvain,
        "Infomap": algorithms.infomap,
        "Walktrap": algorithms.walktrap
    }
    fig = plt.figure()
    plt.xlabel('µ')
    plt.ylabel('Normalized mutual information')
    plt.xticks(mus)

    for algo_name in algs:
        print('ALGORITHM:', algo_name)
        nmis = compare_on_synthetic(algs[algo_name], mus, iter_num)
        plt.plot(mus, nmis, label=algo_name)
        print('======================'*3)
        
    plt.savefig("images/2_i.jpg")
    plt.legend(loc="best")

run()
# Out:
# ALGORITHM: Louvain
# mu=0.00, NMI: 1.000
# mu=0.10, NMI: 1.000
# mu=0.20, NMI: 1.000
# mu=0.30, NMI: 0.998
# mu=0.40, NMI: 0.953
# mu=0.50, NMI: 0.389
# ==================================================================
# ALGORITHM: (DC)SBM
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14668/53971904.py in <module>
#      49 for algo_name in algs:
#      50     print('ALGORITHM:', algo_name)
# ---> 51     nmis = compare_on_synthetic(algs[algo_name], mus, iter_num)
#      52     print('======================'*3)
#
# ~\AppData\Local\Temp/ipykernel_14668/53971904.py in compare_on_synthetic(algo_fn, mus, iter_num)
#      23             if algo_fn == infomap:
#      24                 G = igraph.Graph.from_networkx(G)
# ---> 25             clustered_G = algo_fn(G)
#      26             partition = get_graph_ideal_partition(G)
#      27             NMI += clustered_G.normalized_mutual_information(partition).score / iter_num
#
# TypeError: 'module' object is not callable

# %% [markdown]
# ### (ii)

# %%
def read_net(folder, graph_name):
    file_name = graph_name + '.net'
    G = nx.MultiGraph(name = file_name)
    with open(os.path.join(folder, file_name), 'r', encoding='utf8') as f:
        f.readline()
        # add nodes
        for line in f:
            if line.startswith("*"):
                break
            else:
                node_info = line.split("\"")
                node = int(node_info[0]) - 1
                label = node_info[1]
                cluster = int(node_info[2]) if len(node_info) > 2 and len(node_info[2].strip()) > 0 else 0
                G.add_node(node, label=label, cluster=cluster)

        # add edges
        for line in f:
            node1_str, node2_str = line.split()[:2]
            G.add_edge(int(node1_str)-1, int(node2_str)-1)
    return G

def compare_on_lrf(algo_fn, mus, iter_num=10):
    nmis = []
    for mu in mus:
        NMI = 0
        for i in range(iter_num):
            G = read_net("data/LFR/", "LFR_0{}_{}".format(int(mu*10), i))
            clustered_G = algo_fn(G)
            partition = get_graph_ideal_partition(G) 
            NMI += clustered_G.normalized_mutual_information(partition).score / iter_num
            nmis.append(NMI)
        print("mu={:.2f}, NMI: {:5.3f}".format(mu, NMI))
    return nmis
        
def get_graph_ideal_partition(G):
    P = {}
    for node in G.nodes(data = True):
        if node[1]['cluster'] not in P:
            P[node[1]['cluster']] = []
        P[node[1]['cluster']].append(node[0])
    node_clusters = P.values()
    return NodeClustering(list(node_clusters), G, 'Ideal')

iter_num = 25
mus = [0.2 * i for i in range(0, 5)]

for algo_name in algs:
    print('ALGORITHM:', algo_name)
    nmis = compare_on_lrf(algs[algo_name], mus, iter_num)
    print('======================'*3)
# Out:
# ALGORITHM: Louvain
# mu=0.00, NMI: 0.995
# mu=0.20, NMI: 0.949
# mu=0.40, NMI: 0.868
# mu=0.60, NMI: 0.508
# mu=0.80, NMI: 0.133
# ==================================================================
# ALGORITHM: Walktrap
# mu=0.00, NMI: 1.000
# mu=0.20, NMI: 0.975
# mu=0.40, NMI: 0.820
# mu=0.60, NMI: 0.607
# mu=0.80, NMI: 0.427
# ==================================================================
# ALGORITHM: Label propagation
# mu=0.00, NMI: 0.998
# mu=0.20, NMI: 0.965
# mu=0.40, NMI: 0.888
# mu=0.60, NMI: 0.000
# mu=0.80, NMI: 0.000
# ==================================================================

# %% [markdown]
# ### (iii)

# %%
def compare_on_random(algo_fn, mus, iter_num=10):
    nmis = []
    for mu in mus:
        NMI = 0
        for i in range(iter_num):
            G = nx.gnm_random_graph(1000, 1000*mu)
            clustered_G = algo_fn(G)
            partition = NodeClustering([[r] for r in range(1000)], graph=None, method_name="rand_graph")
            NMI += clustered_G.variation_of_information(partition).score / iter_num
        nmis.append(NMI)
        print("mu={:.2f}, NMI: {:5.3f}".format(mu, NMI))
    return nmis


iter_num = 25
mus = [8 * i for i in range(1, 6)]
for algo_name in algs:
    print('ALGORITHM:', algo_name)
    nmis = compare_on_random(algs[algo_name], mus, iter_num)
    print('======================'*3)
# Out:
# ALGORITHM: Louvain
# mu=8.00, NMI: 7.072
# mu=16.00, NMI: 6.692
# mu=24.00, NMI: 6.820
# mu=32.00, NMI: 6.826
# mu=40.00, NMI: 6.772
# ==================================================================
# ALGORITHM: Walktrap
# mu=8.00, NMI: 5.902
# mu=16.00, NMI: 6.582
# mu=24.00, NMI: 6.778
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7448/3773026564.py in <module>
#      17 for algo_name in algs:
#      18     print('ALGORITHM:', algo_name)
# ---> 19     nmis = compare_on_random(algs[algo_name], mus, iter_num)
#      20     print('======================'*3)
#
# ~\AppData\Local\Temp/ipykernel_7448/3773026564.py in compare_on_random(algo_fn, mus, iter_num)
#       4         NMI = 0
#       5         for i in range(iter_num):
# ----> 6             G = nx.gnm_random_graph(1000, 1000*mu)
#       7             clustered_G = algo_fn(G)
#       8             partition = NodeClustering([[r] for r in range(1000)], graph=None, method_name="rand_graph")
#
# ~\AppData\Roaming\Python\Python37\site-packages\networkx\utils\decorators.py in argmap_gnm_random_graph_5(n, m, seed, directed)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# ~\AppData\Roaming\Python\Python37\site-packages\networkx\generators\random_graphs.py in gnm_random_graph(n, m, seed, directed)
#     282     while edge_count < m:
#     283         # generate random edge,u,v
# --> 284         u = seed.choice(nlist)
#     285         v = seed.choice(nlist)
#     286         if u == v or G.has_edge(u, v):
#
# c:\program files\python37\lib\random.py in choice(self, seq)
#     257         """Choose a random element from a non-empty sequence."""
#     258         try:
# --> 259             i = self._randbelow(len(seq))
#     260         except ValueError:
#     261             raise IndexError('Cannot choose from an empty sequence') from None
#
# KeyboardInterrupt:

# %%
import math

def compare_on_random(algo_fn, mus, iter_num=10):
    nmis = []
    n = 1000
    for mu in mus:
        NMI = 0
        for i in range(iter_num):
            G = nx.gnm_random_graph(n, n/2*mu)
            clustered_G = algo_fn(G)
            partition = NodeClustering([[r] for r in range(n)], graph=G, method_name="rand_graph")
            NMI += clustered_G.variation_of_information(partition).score / math.log(n)
        nmis.append(NMI)
        print("mu={:.2f}, NMI: {:5.3f}".format(mu, NMI))
    return nmis


iter_num = 25
algs = {
    "Louvain": algorithms.louvain,
    "Infomap": algorithms.infomap,
    "Walktrap": algorithms.walktrap
}
mus = [8 * i for i in range(1, 6)]
for algo_name in algs:
    print('ALGORITHM:', algo_name)
    nmis = compare_on_random(algs[algo_name], mus, iter_num)
    print('======================'*3)
# Out:
# ALGORITHM: Louvain
# mu=8.00, NMI: 22.276
# mu=16.00, NMI: 25.462
# mu=24.00, NMI: 24.529
# mu=32.00, NMI: 24.444
# mu=40.00, NMI: 24.378
# ==================================================================
# ALGORITHM: Infomap
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\cdlib\algorithms\crisp_partition.py in infomap(g_original, flags)
#    1082         try:
# -> 1083             from wurlitzer import pipes
#    1084         except ModuleNotFoundError:
#
# ModuleNotFoundError: No module named 'wurlitzer'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5144/2729602425.py in <module>
#      25 for algo_name in algs:
#      26     print('ALGORITHM:', algo_name)
# ---> 27     nmis = compare_on_random(algs[algo_name], mus, iter_num)
#      28     print('======================'*3)
#
# ~\AppData\Local\Temp/ipykernel_5144/2729602425.py in compare_on_random(algo_fn, mus, iter_num)
#       8         for i in range(iter_num):
#       9             G = nx.gnm_random_graph(n, n/2*mu)
# ---> 10             clustered_G = algo_fn(G)
#      11             partition = NodeClustering([[r] for r in range(n)], graph=G, method_name="rand_graph")
#      12             NMI += clustered_G.variation_of_information(partition).score / math.log(n)
#
# ~\AppData\Roaming\Python\Python37\site-packages\cdlib\algorithms\crisp_partition.py in infomap(g_original, flags)
#    1084         except ModuleNotFoundError:
#    1085             raise ModuleNotFoundError(
# -> 1086                 "Optional dependency not satisfied: install package wurlitzer to use infomap."
#    1087             )
#    1088
#
# ModuleNotFoundError: Optional dependency not satisfied: install package wurlitzer to use infomap.

# %% [markdown]
# ## 3. Peers, ties and the Internet

# %%
def leiden(G, node_pairs):
    coms = algorithms.leiden(G)
    C = dict()
    for i in range(len(coms.communities)):
        for node in coms.communities[i]:
            C[node] = i
    part_G = community_louvain.induced_graph(C, G)

    scores = []
    for n1, n2 in node_pairs:
        score = 0
        if C[n1] == C[n2]:
            try: 
                nc = len(coms.communities[C[n1]])
                mc = part_G[C[n1]][C[n2]]['weight']
                score = mc / (nc * (nc-1) / 2)
            except KeyError:
                score = 0
        scores.append([n1, n2, score])
    return scores

def sample(G, p):
    nodes = list(G.nodes())
    N = int(G.number_of_edges()*p)
    
    Ln = []
    while len(Ln) != N:
        node1, node2 = random.choice(nodes), random.choice(nodes)
        if not G.has_edge(node1, node2) and (node1, node2) not in Ln:
            Ln.append((node1, node2))
    
    Lp = random.sample(list(G.edges()), N)
    G.remove_edges_from(Lp)  
    
    return G, [*Ln, *Lp], len(Ln), N

def AUC(G, algs):
    G, nodes, l, N = sample(G.copy(), 0.1)

    scores = []
    for algo_name in algs:
        predicted = list(algs[algo_name](G, nodes))
        m1, m2 = 0, 0
        for n in range(N):
            s1 = random.sample(predicted[:l], 1)[0]
            s2 = random.sample(predicted[l:], 1)[0]
            if s2[2] > s1[2]:
                m1 += 1
            elif s1[2] == s2[2]:
                m2 +=1
        scores.append((m1 + m2/2) / N)
    return np.array(scores)

def AUC_runs(G, name, algs, n=10):
    auc_l, auc_p, auc_a = 0, 0, 0
    for i in range(n):
        scores = AUC(G, algs)
        auc_l += scores[0]
        auc_p += scores[1]
        auc_a += scores[2]
    print(name + ':')
    print("  Leiden:", auc_l/n)
    print("  Preferential attachment:", auc_p/n)
    print("  Adamic adar index:", auc_a/n)

# %%
algs = {
    "Leiden": leiden,
    "Pref attachment": nx.preferential_attachment,
    "Adamic adar index": nx.adamic_adar_index
}
# **********************************************************
G = nx.Graph(nx.read_pajek("data/gnutella.net")).to_undirected()
AUC_runs(G, "Gnutella", algs, 10)
# **********************************************************
G = nx.Graph(nx.read_pajek("data/circles.net")).to_undirected()
AUC_runs(G, "Facebook", 10)
# **********************************************************
G = nx.Graph(nx.read_pajek("data/nec.net")).to_undirected()
AUC_runs(G, "Internet", 10)
# **********************************************************
G = nx.gnm_random_graph(25000, 125000)
AUC_runs(G, "Random", algs, 10)
# Out:
# 4553
# 58
# 3762
# 58
# 654
# 56
# 3762
# 58
# 4463
# 59
# 4463
# 59
# 13104
# 60
# 13104
# 60
# 13104
# 60
# 4505
# 58
#
# 4482
# 56
# 14309
# 61
# 14309
# 61
# 4471
# 56
# 4482
# 56
# 14309
# 61
# 14309
# 61
# 5202
# 58
# 14309
# 61
# 1048
# 56
# 14309
# 61
# 2221
# 56
# 5202
# 58
# 14309
# 61
# 4448
# 57
# 4517
# 56
# 4471
# 56
# 14309
# 61
# 14309
# 61
# 14309
# 61
# 14309
# 61
# 14309
# 61
# 14309
# 61
# 4517
# 56
# 14309
# 61
# 14309
# 61
# 14309
# 61
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5144/1052920791.py in <module>
#       5     "Adamic adar index": nx.adamic_adar_index
#       6 }
# ----> 7 AUC_runs(G, "Gnutella", algs, 10)
#
# ~\AppData\Local\Temp/ipykernel_5144/3284437012.py in AUC_runs(G, name, algs, n)
#      57     scores = np.zeros(3, dtype="float")
#      58     for i in range(n):
# ---> 59         scores += AUC(G, algs)
#      60     print(name + ':')
#      61     print("  Leiden:", scores[0]/n)
#
# ~\AppData\Local\Temp/ipykernel_5144/3284437012.py in AUC(G, algs)
#      38
#      39 def AUC(G, algs):
# ---> 40     G, nodes, l, N = sample(G.copy(), 0.1)
#      41
#      42     scores = []
#
# ~\AppData\Roaming\Python\Python37\site-packages\networkx\classes\graph.py in copy(self, as_view)
#    1544         G.add_edges_from(
#    1545             (u, v, datadict.copy())
# -> 1546             for u, nbrs in self._adj.items()
#    1547             for v, datadict in nbrs.items()
#    1548         )
#
# ~\AppData\Roaming\Python\Python37\site-packages\networkx\classes\graph.py in add_edges_from(self, ebunch_to_add, **attr)
#     951                 self._node[v] = self.node_attr_dict_factory()
#     952             datadict = self._adj[u].get(v, self.edge_attr_dict_factory())
# --> 953             datadict.update(attr)
#     954             datadict.update(dd)
#     955             self._adj[u][v] = datadict
#
# KeyboardInterrupt:

# %%
Ln, Lp, G, N = sample(G.copy(), 0.1)

index = len(Ln)
predicted = predict(G, Ln, Lp)

# %%
G = nx.Graph(nx.read_pajek("data/circles.net")).to_undirected()
AUC_runs(G, "Facebook", 10)
# Out:
# Gnutella:
#   Leiden: 0.9557350107673127
#   Preferential attachment: 0.8314065510597303
#   Adamic adar index: 0.9929049076277909

# %%
G = nx.Graph(nx.read_pajek("data/nec.net")).to_undirected()
AUC_runs(G, "Internet", 10)
# Out:
# Internet:
#   Leiden: 0.8994864403459182
#   Preferential attachment: 0.8232417228736951
#   Adamic adar index: 0.6972222999636171

# %% [markdown]
# ## 4. Get at least 70% right!

# %%
def read_and_split(filepath):
    G = nx.Graph() 

    with open(filepath, 'r') as f:
        f.readline()
        test = []
        for line in f:
            if line.startswith("*"):
                continue

            l = line.split()
            if len(l) == 3:
                if l[1][-3:-1] == '13':
                    G.add_node(int(l[0]))
                    test.append([int(l[0]), l[2]])
                else:
                    G.add_node(int(l[0]), label=l[2])
            else:
                G.add_edge(int(l[0]), int(l[1]))

    return G, test

# %%
G, test = read_and_split("data/aps_2008_2013.net")
predicted = node_classification.harmonic_function(G)

count = 0
for (node, label) in test:
    if predicted[node-1] == label:
        count += 1

acc = count / len(test)
acc
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5144/2053519900.py in <module>
#       1 G, test = read_and_split("data/aps_2008_2013.net")
# ----> 2 predicted = node_classification.harmonic_function(G)
#       3
#       4 count = 0
#       5 for (node, label) in test:
#
# ~\AppData\Roaming\Python\Python37\site-packages\networkx\utils\decorators.py in argmap_harmonic_function_28(G, max_iter, label_name)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# ~\AppData\Roaming\Python\Python37\site-packages\networkx\algorithms\node_classification\hmn.py in harmonic_function(G, max_iter, label_name)
#     124     F = _init_label_matrix(n_samples, n_classes)
#     125
# --> 126     P = _build_propagation_matrix(X, labels)
#     127     B = _build_base_matrix(X, labels, n_classes)
#     128
#
# ~\AppData\Roaming\Python\Python37\site-packages\networkx\algorithms\node_classification\hmn.py in _build_propagation_matrix(X, labels)
#      86         D = sp.sparse.diags((1.0 / degrees), offsets=0)
#      87         P = (D @ X).tolil()
# ---> 88         P[labels[:, 0]] = 0  # labels[:, 0] indicates IDs of labeled nodes
#      89         return P
#      90
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\sparse\lil.py in __setitem__(self, key, x)
#     331             return self._set_intXint(key[0], key[1], x)
#     332         # Everything else takes the normal path.
# --> 333         IndexMixin.__setitem__(self, key, x)
#     334
#     335     def _mul_scalar(self, other):
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\sparse\_index.py in __setitem__(self, key, x)
#     123                 return
#     124             x = x.reshape(i.shape)
# --> 125             self._set_arrayXarray(i, j, x)
#     126
#     127     def _validate_indices(self, key):
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\sparse\lil.py in _set_arrayXarray(self, row, col, x)
#     302
#     303     def _set_arrayXarray(self, row, col, x):
# --> 304         i, j, x = map(np.atleast_2d, _prepare_index_for_memoryview(row, col, x))
#     305         _csparsetools.lil_fancy_set(self.shape[0], self.shape[1],
#     306                                     self.rows, self.data,
#
# ~\AppData\Roaming\Python\Python37\site-packages\scipy\sparse\lil.py in _prepare_index_for_memoryview(i, j, x)
#     519     if x is not None:
#     520         if not x.flags.writeable:
# --> 521             x = x.copy()
#     522         return i, j, x
#     523     else:
#
# MemoryError: Unable to allocate 50.0 GiB for an array with shape (74467, 90162) and data type float64

# %%
def build_synhtetic_graph(mu = 0.5):
    G = nx.Graph(name = "girvan_newman")
    n = 72
    cluster_div = 24
    for i in range(n):
        G.add_node(i, cluster = i // cluster_div + 1)
    for i in range(n):
        for j in range(i + 1, n):
            if G.nodes[i]['cluster'] == G.nodes[j]['cluster']:
                if random.random() < 720 * (1 - mu) / (cluster_div-1):
                    G.add_edge(i, j)
            else:
                if random.random() < 720 * mu / (n-cluster_div):
                    G.add_edge(i, j)
    return G

# %%
G = build_synhtetic_graph(0)

# %%
2*len(list(G.edges()))/72
# Out:
# 20.52777777777778

# %%
nx.connected_components(G)
# Out:
# <generator object connected_components at 0x0000019926BCD6C8>

# %%
NodeClustering([[r] for r in range(10)], graph=G, method_name="rand_graph")
